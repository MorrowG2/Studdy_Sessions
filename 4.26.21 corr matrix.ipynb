# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Kaggle'
# Out:
# /content/drive/My Drive/Kaggle

# %%
import pandas as pd

df = pd.read_csv('titanic_train.csv')
summer = pd.read_csv('summer.csv')
df.head()
# Out:
#    passenger_id  pclass  ...                 home.dest survived
# 0          1216       3  ...                       NaN        1
# 1           699       3  ...                   Croatia        0
# 2          1267       3  ...                       NaN        0
# 3           449       2  ...      Cornwall / Akron, OH        1
# 4           576       2  ...  Barre, Co Washington, VT        0
#
# [5 rows x 15 columns]

# %%
women = df.sex =='female'
age = df.age < 14

(women | age).head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
df.loc[women | age]
# Out:
#      passenger_id  pclass  ...                          home.dest survived
# 0            1216       3  ...                                NaN        1
# 2            1267       3  ...                                NaN        0
# 3             449       2  ...               Cornwall / Akron, OH        1
# 7             560       2  ...           Finland / Washington, DC        1
# 8            1079       3  ...                                NaN        1
# ..            ...     ...  ...                                ...      ...
# 840          1256       3  ...                                NaN        1
# 841           208       1  ...                    Fond du Lac, WI        1
# 842           709       3  ...  Co Longford, Ireland New York, NY        1
# 847           467       2  ...                 Moscow / Bronx, NY        1
# 848          1112       3  ...                                NaN        0
#
# [340 rows x 15 columns]

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#               passenger_id    pclass       age  ...      fare      body  survived
# passenger_id      1.000000  0.896525 -0.340788  ... -0.480013 -0.027040 -0.305726
# pclass            0.896525  1.000000 -0.406071  ... -0.560884 -0.089349 -0.329360
# age              -0.340788 -0.406071  1.000000  ...  0.194609  0.168140 -0.042683
# sibsp             0.098996  0.074418 -0.251310  ...  0.141797 -0.121234 -0.044980
# parch            -0.000191 -0.006388 -0.159216  ...  0.246414  0.131441  0.059172
# fare             -0.480013 -0.560884  0.194609  ...  1.000000 -0.084357  0.251249
# body             -0.027040 -0.089349  0.168140  ... -0.084357  1.000000       NaN
# survived         -0.305726 -0.329360 -0.042683  ...  0.251249       NaN  1.000000
#
# [8 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(corr_matrix,
            annot=True,
            linewidth=0.5,
            fmt='.2f',
            cmap='YlGnBu');
